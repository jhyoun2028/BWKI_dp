# %% [markdown]
# # 02 – Baseline: TF-IDF + logistische Regression
#
# Dünnes Notebook: die gesamte Logik steht in `src/train_baseline.py`.
# Hier wird das Skript aufgerufen und die Konfusionsmatrix angezeigt.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
sys.path.insert(0, str(ROOT / "src"))

import train_baseline
train_baseline.main()

# %%
import json
from IPython.display import Image, display

display(Image(ROOT / "results" / "confusion_matrix_baseline.png"))
m = json.load(open(ROOT / "results" / "metrics.json", encoding="utf-8"))["baseline_tfidf_logreg"]
print(json.dumps({"train": m["train"], "test": m["test"], "test_de": m["test_de"]}, indent=2))
